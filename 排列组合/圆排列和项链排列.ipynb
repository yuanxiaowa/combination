# %% [markdown]
# ## 圆排列
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 项链排列
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 例题

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
