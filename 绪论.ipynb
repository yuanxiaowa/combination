# %%
def p(n, m):
    t = 1
    for i in range(m):
        t *= n - i
    return t

def c(n, m):
    return p(n, m) / p(m, m)

# %% [markdown]
# ## iphone手机密码总数
# $10^4$

# %%
10**4
# Out:
# 10000

# %% [markdown]
# ## 安卓滑动密码
#
# 总密码数(不考虑顺序)
# $C_9^4+C_9^5+C_9^6+C_9^7+C_9^8+C_9^9$

# %%
c(9,4)+c(9,5)+c(9,6)+c(9,7)+c(9,8)+c(9,9)
# Out:
# 382.0

# %% [markdown]
# 考虑顺序
# $C_9^4 4!+C_9^5 5!+C_9^6 6!+C_9^7 7!+C_9^8 8!+C_9^9 9!$

# %%
c(9,4)*p(4,4)+c(9,5)*p(5,5)+c(9,6)*p(6,6)+c(9,7)*p(7,7)+c(9,8)*p(8,8)+c(9,9)*p(9,9)
# Out:
# 985824.0

# %% [markdown]
# 考虑不合法的情况
#
# > 如果选择的两个点练成的线段，穿越了第三个点，如果之前这第三个点，没有被连过，则不合法；反之则合法。
#
# 总数 389112
# - 4位密码 1624
# - 5位密码 7152

# %% [markdown]
# ## 世界杯复赛需要踢多少场？
# 16支球队进入复赛

# %% [markdown]
# 每场比赛淘汰一支，冠军只有一个，淘汰多少个球队就要踢多少场

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 哥尼斯堡七桥问题

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 一笔画问题

# %% [markdown]
# ![image.png](attachment:image.png)
